# %% [markdown]
# <a href="https://colab.research.google.com/github/TrollfaceGaming69/ScientificComputing/blob/main/modul2_alfatih.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as jawa

A = jawa.array([[2, 3, -1],
              [1, -1, 2],
              [3, 2, 1]])
B = jawa.array([10, 4, 14])

x = 5
y = 5
z = 5
epsilon = 0.001
converged = False

x_old = jawa.array([x, y, z])

for k in range(1, 4):
  x = (10 - 1*y + 3*z) / 2
  y = (4 + 2*x - 1*z) / 1
  z = (14 + 1*x + 2*y) / 3

  x_new = jawa.array([x, y, z])
  dx = jawa.sqrt(jawa.dot(x_new - x_old, x_new - x_old))

x_numpy = jawa.linalg.solve(A, B)

print(f"Gauss seidel:  x ={x:.4f}, y={y:.4f}, z={z:.4f}")

print(f"Numpy:" f"x1 = {x_numpy[0]:.4f}, x2 = {x_numpy[1]:.4f}, x3 = {x_numpy[2]:.4f}")
# Out:
# Gauss seidel:  x =43.4167, y=53.1111, z=54.5463
# Numpy:x1 = 0.6500, x2 = 4.1500, x3 = 3.7500

# %%
import numpy as jawa

A = jawa.array([[3, -0.1, -0.2],
              [0.1, 7, -0.3],
              [0.3, -0.2, 10]])
B = jawa.array([7.85, -19.3, 71.4])

x = 1
y = 2
z = 3
epsilon = 0.001
converged = False

x_old = jawa.array([x, y, z])

for k in range(1, 4):
  x = (7.85 + 0.1*y + 0.2*z) / 3
  y = (-19.3 - 0.1*x + 0.3*z) / 7
  z = (71.4 - 0.3*x + 0.2*y) / 10

  x_new = jawa.array([x, y, z])
  dx = jawa.sqrt(jawa.dot(x_new - x_old, x_new - x_old))


x_numpy = jawa.linalg.solve(A, B)

print(f"Gauss seidel:  x ={x:.4f}, y={y:.4f}, z={z:.4f}")

print(f"Numpy:" f"x1 = {x_numpy[0]:.4f}, x2 = {x_numpy[1]:.4f}, x3 = {x_numpy[2]:.4f}")
# Out:
# Gauss seidel:  x =3.0000, y=-2.5000, z=7.0000
# Numpy:x1 = 3.0000, x2 = -2.5000, x3 = 7.0000

# %%
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

X = [5, 4, 6, 7, 5]
Y = [10, 8, 12, 14, 10]

x = np.linspace(0, 1, 101)
y = 1 + x + x * np.random.random(len(x))

A = np.vstack([x, np.ones(len(x))]).T

y = y[:, np.newaxis]

alpha = np.dot((np.dot(np.linalg.inv(np.dot(A.T,A)),A.T)),y)

print(alpha)

plt.figure(figsize=(10, 8))
plt.plot(x, y, 'b.', label='Data')
plt.plot(x, alpha[0]*x + alpha[1], 'r', label ='Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# [[1.42090857]
#  [1.02615712]]
